# %%
#Guide for Processing Sessions with Dreadds2 Class
#Imports & Setup
from myphdlib.interface.dreadds2 import Dreadds2Session
from myphdlib.interface.NR1KO import NR1Session
from myphdlib.interface.nope import NOPESession
from myphdlib.pipeline.prediction import predictSaccadeDirection
from myphdlib.pipeline.prediction import predictSaccadeEpochs
import matplotlib.pylab as plt
import os
import re
import numpy as np
from myphdlib.general.labjack import loadLabjackData
import nptracer as npt
#session = Dreadds2Session('filepath')

# %%
#these are the sessions we're actively processing
sessionsToProcess = list()
sessionsList = ['/media/jbhunt/EPHYS-01/7-31-25/square',
                '/media/jbhunt/EPHYS-01/7-31-25/trapezoid',
                '/media/jbhunt/EPHYS-01/7-31-25/slepian',
                '/media/jbhunt/EPHYS-01/7-31-25/triangle',
                '/media/jbhunt/EPHYS-01/7-31-25/rampupdown',
                '/media/jbhunt/EPHYS-01/7-31-25/exponential',
                '/media/jbhunt/EPHYS-01/7-31-25/gaussian',
                '/media/jbhunt/EPHYS-01/7-31-25/raisecosine'
                
               ]
for session in sessionsList:
    sessionsToProcess.append(NOPESession(session))

# %%
#this is a list of all sessions that have been processed, required for saccade prediction
sessionsAll = list()
sessionsAllList = [
            '/media/jbhunt/Seagate Portable Drive/NPData/2024-02-28/DREADD9', 
               '/media/jbhunt/Seagate Portable Drive/NPData/2024-03-01/DREADD9', 
               '/media/jbhunt/Seagate Portable Drive/NPData/2024-03-27/DREADD10',
               '/media/jbhunt/Seagate Portable Drive/NPData/2024-03-27/DREADD13', 
               '/media/jbhunt/Seagate Portable Drive/NPData/2024-04-06/DREADD10', 
               '/media/jbhunt/Seagate Portable Drive/NPData/2024-04-06/DREADD13', 
              '/media/jbhunt/Seagate Portable Drive/NPData/2024-04-07/DREADD10', 
               '/media/jbhunt/Seagate Portable Drive/NPData/2024-04-07/DREADD13', 
               '/media/jbhunt/Seagate Portable Drive/NPData/2024-04-08/DREADD10', 
              '/media/jbhunt/Seagate Portable Drive/NPData/2024-04-09/DREADD10', 
               '/media/jbhunt/Seagate Portable Drive/NPData/2024-04-09/DREADD13',
              '/media/jbhunt/Seagate Portable Drive/NPData/2024-02-23/DREADD9',
               '/media/jbhunt/Seagate Portable Drive/NPData/2024-02-23/DREADD11',
               '/media/jbhunt/Seagate Portable Drive/NPData/2024-02-26/DREADD9',
               '/media/jbhunt/Seagate Portable Drive/NPData/2024-02-26/DREADD11',
               '/media/jbhunt/Seagate Portable Drive/NPData/2024-02-27/DREADD9',
               '/media/jbhunt/Seagate Portable Drive/NPData/2024-02-27/DREADD11',
               '/media/jbhunt/Seagate Portable Drive/NPData/2024-02-28/DREADD11',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-03/dreaddtest1',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-03/dreaddtest2',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-03/dreaddtest3',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-03/dreaddtest4',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-04/dreaddtest1',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-04/dreaddtest2',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-04/dreaddtest3',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-04/dreaddtest4',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-05/dreaddtest1',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-05/dreaddtest2',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-05/dreaddtest4',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-06/dreaddtest1',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-06/dreaddtest2',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-06/dreaddtest4',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-14/DREADD2.2',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-14/DREADD3.2',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-14/DREADD4.2',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-15/DREADD2.2',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-15/DREADD3.2',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-15/DREADD4.2',
                '/media/jbhunt/Seagate Portable Drive/NPData/2024-06-18/dreadd3.2'
                #'/media/retina2/Seagate Portable Drive/NPData/2024-06-18/dreadd4.2',
              #  '/media/retina2/Seagate Portable Drive/NPData/2024-06-19/dreadd3.2',
               # '/media/retina2/Seagate Portable Drive/NPData/2024-06-19/dreadd4.2',
                #'/media/retina2/Seagate Portable Drive/NPData/2024-06-20/dreadd2.2',
               # '/media/retina2/Seagate Portable Drive/NPData/2024-06-20/dreadd4.2',
               # '/media/retina2/Seagate Portable Drive/NPData/2024-06-21/dreadd2.2',
               # '/media/retina2/Seagate Portable Drive/NPData/2024-06-21/dreadd4.2',
              #  '/media/retina2/Seagate Portable Drive/NPData/2024-06-22/dreadd2.2',
               # '/media/retina2/Seagate Portable Drive/NPData/2024-06-22/dreadd4.2',
              #  '/media/retina2/Seagate Portable Drive/NPData/2024-06-23/dreadd2.2',
              #  '/media/retina2/Seagate Portable Drive/NPData/2024-06-24/dreadd2.2',
              #  '/media/retina2/Seagate Portable Drive/NPData/2024-06-24/dreadd4.2',
              #  '/media/retina2/Seagate Portable Drive/NPData/2024-06-25/dreadd2.2',
               # '/media/retina2/Seagate Portable Drive/NPData/2024-06-25/dreadd4.2',
               # '/media/retina2/Seagate Portable Drive/NPData/2024-06-26/dreadd2.2',
              #  '/media/retina2/Seagate Portable Drive/NPData/2024-06-26/dreadd4.2',
               # '/media/retina2/Seagate Portable Drive/NPData/2024-06-27/dreadd2.2'
               # '/media/retina2/Seagate Portable Drive/NPData/2024-06-27/dreadd4.2',
              #  '/media/retina2/Seagate Portable Drive/NPData/2024-06-28/dreadd4.2'
                #'/media/retina2/EPHYS-01/12-17-24/NR1KOP7007',
                 # '/media/retina2/EPHYS-01/12-18-24/NR1KOP7007',
                  # '/media/retina2/EPHYS-01/12-19-24/NR1KOP7007',
                  # '/media/retina2/EPHYS-01/12-20-24/NR1KOP7007'
                
                  ]
for session in sessionsAllList:
    sessionToAppend = Dreadds2Session(session)
    sessionsAll.append(sessionToAppend)

# %%
#Extracting Saccades
#for session in sessionsJenna:
sessionsToProcess[0]._runSaccadesModule(pupilCenterName = 'pupil-0')
predictSaccadeDirection(sessionsToProcess, sessionsAll) #can modify if adding more sessions so we're not reanalyzing/predicting (we REALLY dont want to repredict things lol)
#session = Dreadds2Session('filepath')
#session._labelSaccadeEpochs(nSamples=10)
predictSaccadeEpochs(sessionsToProcess, sessionsAll)
# Out:
# INFO: (testnope, 2025-07-24) Extracting eye position data
# INFO: (testnope, 2025-07-24) Extracting putative saccades
# WARNING: (testnope, 2025-07-24) Eye position data missing for the right eye
# INFO: (testnope, 2025-07-24) 488 putative saccades detected for the left eye
# INFO: (dreadd9, 2024-02-28) Collected training data for predicting saccade direction (20 samples)
# INFO: (dreadd9, 2024-03-01) Collected training data for predicting saccade direction (20 samples)
# INFO: (dreadd10, 2024-03-27) Collected training data for predicting saccade direction (20 samples)
# INFO: (dreadd13, 2024-03-27) Collected training data for predicting saccade direction (20 samples)
# INFO: (dreadd10, 2024-04-06) Collected training data for predicting saccade direction (20 samples)
# INFO: (dreadd13, 2024-04-06) Collected training data for predicting saccade direction (20 samples)
# INFO: (dreadd10, 2024-04-07) Collected training data for predicting saccade direction (20 samples)
# ...

# %%
#do this if we want manually labeled saccades
csvFile = '/home/retina2/Downloads/12-19-24_manual_extraction.xlsx'
#sessionsNR1[4].pullManuallyLabeledSaccades(csvFile)

#sessionsNR1[0]._determineGratingMotionAssociatedWithEachSaccade(manualLabeling=False) #set this flag 
metadataHolder = sessionsNR1[0]._runStimuliModule()
# Out:
# smoothed
# 20
# 19
# /media/retina2/EPHYS-01/12-5-24/control002/videos/driftingGratingMetadata-0.txt
# 304
# 304
# /media/retina2/EPHYS-01/12-5-24/control002/videos/driftingGratingMetadata-1.txt
# 305
# 305
# /media/retina2/EPHYS-01/12-5-24/control002/videos/driftingGratingMetadata-2.txt
# 306
# 306
# /media/retina2/EPHYS-01/12-5-24/control002/videos/driftingGratingMetadata-3.txt
# 312
# 311
# /media/retina2/EPHYS-01/12-5-24/control002/videos/driftingGratingMetadata-4.txt
# 305
# 305
# /media/retina2/EPHYS-01/12-5-24/control002/videos/driftingGratingMetadata-5.txt
# 304
# 304
# /media/retina2/EPHYS-01/12-5-24/control002/videos/driftingGratingMetadata-6.txt
# 309
# 309
# /media/retina2/EPHYS-01/12-5-24/control002/videos/driftingGratingMetadata-7.txt
# 308
# 308
# /media/retina2/EPHYS-01/12-5-24/control002/videos/driftingGratingMetadata-8.txt
# 307
# 307
# /media/retina2/EPHYS-01/12-5-24/control002/videos/driftingGratingMetadata-9.txt
# 311
# 309
# ...

# %%
session.listAllDatasets()
# Out:
# barcodes/labjack/indices
# barcodes/labjack/trains
# barcodes/labjack/values
# barcodes/neuropixels/indices
# barcodes/neuropixels/trains
# barcodes/neuropixels/values
# frames/left/dropped
# frames/left/intervals
# frames/left/timestamps
# frames/right/dropped
# frames/right/intervals
# frames/right/timestamps
# labjack/cameras/missing
# labjack/cameras/timestamps
# labjack/matrix
# labjack/timespace
# metrics/ac
# metrics/fr
# metrics/pr
# metrics/ql
# metrics/rpvr
# pose/corrected
# pose/decomposed
# pose/filtered
# pose/interpolated
# pose/missing/left
# pose/missing/right
# pose/reoriented
# pose/uncorrected
# saccades/predicted/left/dop
# saccades/predicted/left/epochs
# saccades/predicted/left/indices
# saccades/predicted/left/labels
# saccades/predicted/left/timestamps
# saccades/predicted/left/ttp
# saccades/predicted/left/waveforms
# saccades/putative/left/indices
# saccades/putative/left/waveforms
# spikes/clusters
# spikes/timestamps
# stimuli/dg/probe/dos
# ...

# %%
motionOnsetTimestamps = sessionsNR1[1].load('stimuli/dg/grating/timestamps')
motionOffsetTimestamps = sessionsNR1[1].load('stimuli/dg/iti/timestamps')
print(motionOnsetTimestamps.shape)
print(motionOffsetTimestamps.shape)
# Out:
# (38,)
# (38,)

# %%
from matplotlib.pyplot import subplots
from myphdlib.general.labjack import loadLabjackData
#session = NOPESession('/media/jbhunt/EPHYS-01/6-18-25/testNOPE')
# %pylab qt
labjackFolder = '/media/jbhunt/EPHYS-01/7-24-25/squarewave/labjack'
labjackData = loadLabjackData(labjackFolder)
fig, axs = subplots(nrows=15, sharex=True)
for ax, i in zip(axs, range(15)):
    ax.cla()
    ax.plot(labjackData[:, i])
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
#Extract Labjack Event, Ephys & Timestamping Info
#for session in sessionsToProcess:
session = NOPESession('/media/jbhunt/EPHYS-01/nopetangential/9-11-2025/ChR2GAD3')
session._createLabjackDataMatrix()
session._extractLabjackTimespace()
session._extractBarcodeSignals()
session._decodeBarcodeSignals()
session._estimateTimestampingFunction()

# session._runStimuliModule()
# session._determineGratingMotionAssociatedWithEachSaccade(manualLabeling=False) #set this flag 
#session._findDroppedFrames()
#session._timestampCameraTrigger()
#session._timestampVideoFrames()
#session._timestampSaccades()
#session._computeRelativeEventTiming()
#session._runSpikesModule(sorting='manual')
#session._extractSpikeDatasets(sorting='manual') #this flag will depend on which folder kilosort4 output is in
#session._extractReceptiveFields()
# Out:
# INFO: (chr2gad3, 2025-09-11) Creating labjack data matrix

# %%
len(session.load('metrics/ql'))
# Out:
# 457

# %%
#look at everything in H5 file
sessionsNR1[0]._determineGratingMotionAssociatedWithEachSaccade(manualLabeling=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 #look at everything in H5 file
# ----> 2 sessionsNR1[0]._determineGratingMotionAssociatedWithEachSaccade(manualLabeling=False)
#
# File ~/Code/myphdlib/myphdlib/interface/NR1KO.py:543, in NR1Session._determineGratingMotionAssociatedWithEachSaccade(self, manualLabeling)
#     541 motionOnsetTimestamps = self.load('stimuli/dg/grating/timestamps')
#     542 motionOffsetTimestamps = self.load('stimuli/dg/iti/timestamps')
# --> 543 gratingEpochs = np.hstack([
#     544     motionOnsetTimestamps.reshape(-1, 1),
#     545     motionOffsetTimestamps.reshape(-1, 1)
#     546 ])
#     548 #
#     549 nBlocks = gratingEpochs.shape[0]
#
# File <__array_function__ internals>:180, in hstack(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/core/shape_base.py:345, in hstack(tup)
# ...

# %%
sess = Dreadds2Session('/media/retina2/Seagate Portable Drive/2024-06-28/dreadd4.2')
sess._runSpikesModule()
# Out:
# WARNING: (dreadd4.2, 2024-06-28) Could not locate cluster info file
# INFO: (dreadd4.2, 2024-06-28) Measuring spike-sorting quality
# ecephys spike sorting: quality metrics module
# Loading metric_data...
# Unpacking and starting calculations..
# Calculating isi violations
#  ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒ 100%
# Calculating presence ratio
#  ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒ 100%
# Calculating firing rate
#  ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒ 100%
# Calculating amplitude cutoff
#  ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒ 100%
# total time: 23.87 seconds
# Saving metrics to file '/media/retina2/Seagate Portable Drive/2024-06-28/dreadd4.2/ephys/sorting/manual/quality_metrics.json'
